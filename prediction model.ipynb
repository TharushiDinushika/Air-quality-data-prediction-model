# %%
import datetime, warnings, scipy
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rcParams["patch.force_edgecolor"] = True
plt.style.use('fivethirtyeight')
mpl.rc('patch', edgecolor = 'dimgray', linewidth=1)
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "last_expr"
pd.options.display.max_columns = 50
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
#import the functions from Keras and sklearn libraries

import math 
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('D:/Machine Learning/pythonProject/air_quality.csv', sep= ' ')
df.head()
# Out:
#    No  Profile     Tanggal       Jam     O3    CO    NO2    SO2      NO  \
# 0   1  BANDUNG  2019-05-19  00:04:19  21.35  0.78   6.77  14.06  26.168
# 1   2  BANDUNG  2019-05-19  00:15:01   5.93  0.82  14.87  17.23  53.853
# 2   3  BANDUNG  2019-05-19  00:30:06   6.62  0.63  22.24   2.31  38.304
# 3   4  BANDUNG  2019-05-19  00:49:19  13.29  0.44  19.00   5.32  18.962
# 4   5  BANDUNG  2019-05-19  01:04:19   2.44  0.47  26.74  13.61  35.270
#
#       CO2      VOC  PM1  PM2.5  PM4   PM10  TSP  TEMP    HUM     WS  WD  ISPU  \
# 0  409.86  251.202  0.0    0.0  0.0   2.77  0.0  21.4  100.0  0.600   5     9
# 1  394.79  501.356  0.0    0.0  0.0  11.95  0.0  42.6  200.0  0.000   2    12
# 2  390.66  753.291  0.0    0.0  0.0  12.71  0.0  63.6  299.2  0.000   2    13
# 3  401.23  251.043  0.0    0.0  0.0   1.20  0.0  21.3   88.2  0.525   5     6
# 4  381.67  250.471  0.0    0.0  0.0   3.52  0.0  21.3   97.4  0.975   5     9
#
#   Status  Unnamed: 22
# 0   BAIK          NaN
# 1   BAIK          NaN
# 2   BAIK          NaN
# 3   BAIK          NaN
# 4   BAIK          NaN

# %%
#convert time to datatime format

def combine_date (df, tab_name):
    list_tab = []
    for i in range(df.shape[0]):
        list_tab.append(df.loc[i, 'Tanggal']+ 'T'+df.loc[i, tab_name][0:2])
    return np.array(list_tab, dtype='datetime64')
    
df['Datetime'] = combine_date(df, 'Jam')

def combine_date (df, tab_name):
    list_tab = []
    for i in range(df.shape[0]):
        list_tab.append(df.loc[i, 'Tanggal']+ 'T'+df.loc[i, tab_name][0:2])
    return np.array(list_tab, dtype='datetime64')
df['Datetime'] = combine_date(df, 'Jam')

#convert into hourly data
df = df[['Datetime', 'O3', 'CO', 'NO2', 'SO2', 'NO', 'CO2', 'VOC', 'PM1', 'PM2.5', 'PM4', 'PM10', 'TSP', 'TEMP', 'HUM', 'WS', 'WD', 'ISPU']]
#df.head()
df2 = df.groupby(['Datetime']).mean()
df2.head()
# Out:
#                             O3        CO     NO2      SO2        NO  \
# Datetime
# 2019-05-19 00:00:00  11.797500  0.667500  15.720   9.7300  34.32175
# 2019-05-19 01:00:00   3.816667  0.373333  22.600  20.0900  39.82100
# 2019-05-19 02:00:00   6.450000  0.332500  24.130  26.3100  51.29325
# 2019-05-19 03:00:00   4.740000  0.180000  25.975  24.3900  43.51850
# 2019-05-19 04:00:00  19.692500  0.202500  20.395  18.6225  53.37925
#
#                             CO2        VOC  PM1  PM2.5  PM4      PM10  TSP  \
# Datetime
# 2019-05-19 00:00:00  399.135000  439.22300  0.0    0.0  0.0  7.157500  0.0
# 2019-05-19 01:00:00  388.536667  250.39400  0.0    0.0  0.0  3.293333  0.0
# 2019-05-19 02:00:00  396.242500  251.04575  0.0    0.0  0.0  6.487500  0.0
# 2019-05-19 03:00:00  401.355000  252.24875  0.0    0.0  0.0  4.700000  0.0
# 2019-05-19 04:00:00  399.335000  694.23975  0.0    0.0  0.0  5.262500  0.0
#
#                           TEMP         HUM       WS        WD       ISPU
# Datetime
# 2019-05-19 00:00:00  37.225000  171.850000  0.28125  3.500000  10.000000
# 2019-05-19 01:00:00  20.966667   95.033333  0.67500  4.666667  12.666667
# 2019-05-19 02:00:00  20.150000   97.500000  0.09375  3.750000  16.250000
# 2019-05-19 03:00:00  19.850000  100.000000  0.07500  5.000000  15.000000
# 2019-05-19 04:00:00  53.475000  272.500000  0.18750  5.250000  13.250000

# %%
#Description statistics of the variables
df2.describe()
# Out:
#                 O3           CO          NO2          SO2           NO  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      8.538909     0.233172    16.681910    12.013894    37.086256
# std       3.997292     0.388102     5.373487     4.411251    12.521778
# min       0.270000     0.010000     2.040000     2.162500     3.128750
# 25%       5.881667     0.083333    13.010000     9.015000    28.443500
# 50%       7.813333     0.160000    15.916667    11.730000    39.252250
# 75%      10.373333     0.296667    19.935000    14.595000    46.015500
# max      33.741667    13.950000    99.600000    46.290000   194.554000
#
#                CO2          VOC          PM1        PM2.5          PM4  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean    394.616480   260.053778     0.309564     0.383692     0.451982
# std       4.180224    60.773321     2.286104     2.874126     3.378291
# min     380.420000   187.518000     0.000000     0.000000     0.000000
# 25%     391.830000   247.798333     0.000000     0.000000     0.000000
# 50%     394.602000   250.926250     0.000000     0.000000     0.000000
# 75%     397.415000   253.286667     0.000000     0.000000     0.000000
# max     408.820000  1240.713500    51.600000    68.700000    79.800000
#
#               PM10          TSP         TEMP          HUM           WS  \
# count  1737.000000  1737.000000  1737.000000  1737.000000  1737.000000
# mean      6.157770     0.562012    25.266942    77.634191    24.291226
# std       4.149511     4.184787     6.707977    29.743129    51.993683
# min       0.885000     0.000000    11.250000    26.866667     0.000000
# 25%       4.340000     0.000000    21.266667    57.850000     0.237500
# 50%       5.571667     0.000000    24.100000    77.083333     1.312500
# 75%       7.090000     0.000000    28.400000    94.066667     5.075000
# max      91.600000    92.900000   124.600000   313.400000   199.200000
#
#                 WD         ISPU
# count  1737.000000  1737.000000
# mean      7.129031    10.097848
# std       3.523245     5.049788
# min       0.000000     4.250000
# 25%       4.666667     8.166667
# 50%       5.833333     9.500000
# 75%      10.500000    11.000000
# max      15.000000   156.500000

# %%
#calculate quantile for each variable

def calculate_quantile(i, df2):
    Q1 = df2[[i]].quantile(0.25)[0]
    Q3 = df2[[i]].quantile(0.75)[0]
    IQR = Q3 - Q1
    min_value= df2[[i]].min()[0]
    max_value= df2[[i]].max()[0]
    min_IQR = Q1 - 1.5*IQR
    max_IQR = Q3 + 1.5*IQR
    
    return Q1, Q3, min_value, max_value, min_IQR, max_IQR

#delete first and last rows to avoid missing value extrapolation
df2.drop(index=[df2.index[0], df2.index[df2.shape[0]-1]], inplace=True)

#find and interpolate the outliers
for i in df2.columns:
    print('\nAttributr-',i,':')
    Q1, Q3, min_value, max_value, min_IQR, max_IQR = calculate_quantile(i, df2)
    print('Q1 = %.2f' % Q1)
    print('Q3 = %.2f' % Q3)
    print('min IQR = %.2f' % min_IQR)
    print('max IQR = %.2f' % max_IQR)
    if (min_value < min_IQR):
        print('---> Low outlier is found = %.2f' % min_value)
    if (max_value > max_IQR):
        print('---> High outlier is found = %.2f' % max_value)
    def convert_nan (x, max_IQR = max_IQR, min_IQR=min_IQR):
        if((x> max_IQR) | (x< min_IQR)):
            x = np.nan
        else:
            x = x
        return  x
    def convert_nan_HUM (x, max_IQR=100.0, min_IQR=min_IQR):
        if((x>max_IQR) | (x< min_IQR)):
            x = np.nan
        else:
            x=x
        return  x
    if (i == 'HUM'):
        df2[i] = df2[i].map(convert_nan_HUM)
        df2[i] = df2[i].interpolate(method='linear')
    if (i != 'HUM'):
        df2[i] = df2[i].map(convert_nan)
        df2[i] = df2[i].interpolate(method='linear')
        
    if(len(df2[df2[i].isnull()][i]) == 0):
        print('########## Outliers have been interpolated #########')
# Out:
# Attributr- O3 :
# Q1 = 5.87
# Q3 = 10.35
# min IQR = -0.86
# max IQR = 17.09
# ---> High outlier is found = 33.74
# ########## Outliers have been interpolated #########
#
# Attributr- CO :
# Q1 = 0.08
# Q3 = 0.30
# min IQR = -0.24
# max IQR = 0.62
# ---> High outlier is found = 13.95
# ########## Outliers have been interpolated #########
#
# Attributr- NO2 :
# Q1 = 13.01
# Q3 = 19.91
# min IQR = 2.67
# max IQR = 30.25
# ---> Low outlier is found = 2.04
# ---> High outlier is found = 99.60
# ########## Outliers have been interpolated #########
#
# Attributr- SO2 :
# Q1 = 8.98
# Q3 = 14.55
# min IQR = 0.62
# max IQR = 22.92
# ---> High outlier is found = 46.29
# ########## Outliers have been interpolated #########
#
# Attributr- NO :
# Q1 = 28.38
# Q3 = 46.02
# min IQR = 1.93
# max IQR = 72.47
# ---> High outlier is found = 194.55
# ########## Outliers have been interpolated #########
#
# Attributr- CO2 :
# Q1 = 391.83
# Q3 = 397.40
# min IQR = 383.48
# max IQR = 405.75
# ---> Low outlier is found = 380.42
# ---> High outlier is found = 408.82
# ########## Outliers have been interpolated #########
#
# Attributr- VOC :
# Q1 = 247.82
# Q3 = 253.31
# min IQR = 239.59
# max IQR = 261.53
# ---> Low outlier is found = 187.52
# ---> High outlier is found = 1240.71
# ########## Outliers have been interpolated #########
#
# Attributr- PM1 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 51.60
# ########## Outliers have been interpolated #########
#
# Attributr- PM2.5 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 68.70
# ########## Outliers have been interpolated #########
#
# Attributr- PM4 :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 79.80
# ########## Outliers have been interpolated #########
#
# Attributr- PM10 :
# Q1 = 4.34
# Q3 = 7.09
# min IQR = 0.22
# max IQR = 11.21
# ---> High outlier is found = 91.60
# ########## Outliers have been interpolated #########
#
# Attributr- TSP :
# Q1 = 0.00
# Q3 = 0.00
# min IQR = 0.00
# max IQR = 0.00
# ---> High outlier is found = 92.90
# ########## Outliers have been interpolated #########
#
# Attributr- TEMP :
# Q1 = 21.30
# Q3 = 28.42
# min IQR = 10.62
# max IQR = 39.09
# ---> High outlier is found = 124.60
# ########## Outliers have been interpolated #########
#
# Attributr- HUM :
# Q1 = 57.80
# Q3 = 93.95
# min IQR = 3.57
# max IQR = 148.18
# ---> High outlier is found = 313.40
# ########## Outliers have been interpolated #########
#
# Attributr- WS :
# Q1 = 0.24
# Q3 = 5.08
# min IQR = -7.02
# max IQR = 12.33
# ---> High outlier is found = 199.20
# ########## Outliers have been interpolated #########
#
# Attributr- WD :
# Q1 = 4.67
# Q3 = 10.67
# min IQR = -4.33
# max IQR = 19.67
# ########## Outliers have been interpolated #########
#
# Attributr- ISPU :
# Q1 = 8.17
# Q3 = 11.00
# min IQR = 3.92
# max IQR = 15.25
# ---> High outlier is found = 156.50
# ########## Outliers have been interpolated #########

# %%
#log transformation to deal with skewed data

dataset = np.log1p(df2[['TEMP']].values)
dataset.shape
# Out:
# (1721, 1)

# %%
#create new dataframe to compare the original vs log transform data
dist_df = pd.DataFrame({'TEMP': df2['TEMP'].values, 'log_TEMP' : dataset[:,0]})

#histogram plot original vs log transform data
plt.figure(figsize=(12, 5))
dist_df.hist();

# %%
#split the datasset into train and test sets

train_size = int(len(dataset)* 0.75)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset),:]
print(len(train), len(test))
# Out:
# 1290 431

# %%
#convert array of values into a dataset matrix

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

#reshape the train and test data

look_back = 1
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

print('Shape of trainX :', trainX.shape)
print('Shape of trainY :', trainY.shape)
print('Shape of testX :', testX.shape)
print('Shape of testY :', testY.shape)
# Out:
# Shape of trainX : (1288, 1)
# Shape of trainY : (1288,)
# Shape of testX : (429, 1)
# Shape of testY : (429,)

# %%
#reshape the input array in the form -[samples, time steps, features]

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))

print('Shape of trainX:', trainX.shape)
print('Shape of testX:', testX.shape)
# Out:
# Shape of trainX: (1288, 1, 1)
# Shape of testX: (429, 1, 1)

# %%
#create and fit the LSTM Nueral network
model = Sequential()
model.add(LSTM(4, input_shape=(1, look_back)))
model.add(Dense(1))

model.compile(loss='mean_squared_error', optimizer='adam')
model.fit(trainX, trainY, epochs=300, batch_size=32, verbose=2)
# Out:
# Epoch 1/300
# 41/41 - 4s - 108ms/step - loss: 9.0706
# Epoch 2/300
# 41/41 - 0s - 2ms/step - loss: 8.2160
# Epoch 3/300
# 41/41 - 0s - 1ms/step - loss: 7.4531
# Epoch 4/300
# 41/41 - 0s - 2ms/step - loss: 6.6953
# Epoch 5/300
# 41/41 - 0s - 2ms/step - loss: 5.8631
# Epoch 6/300
# 41/41 - 0s - 1ms/step - loss: 4.9521
# Epoch 7/300
# 41/41 - 0s - 2ms/step - loss: 4.0487
# Epoch 8/300
# 41/41 - 0s - 2ms/step - loss: 3.2411
# Epoch 9/300
# 41/41 - 0s - 2ms/step - loss: 2.5635
# Epoch 10/300
# 41/41 - 0s - 5ms/step - loss: 2.0116
# Epoch 11/300
# 41/41 - 0s - 2ms/step - loss: 1.5664
# Epoch 12/300
# 41/41 - 0s - 2ms/step - loss: 1.2098
# Epoch 13/300
# 41/41 - 0s - 2ms/step - loss: 0.9242
# Epoch 14/300
# 41/41 - 0s - 2ms/step - loss: 0.6960
# Epoch 15/300
# 41/41 - 0s - 2ms/step - loss: 0.5135
# Epoch 16/300
# 41/41 - 0s - 2ms/step - loss: 0.3689
# Epoch 17/300
# 41/41 - 0s - 2ms/step - loss: 0.2570
# Epoch 18/300
# 41/41 - 0s - 2ms/step - loss: 0.1732
# Epoch 19/300
# 41/41 - 0s - 2ms/step - loss: 0.1140
# Epoch 20/300
# 41/41 - 0s - 2ms/step - loss: 0.0744
# Epoch 21/300
# 41/41 - 0s - 2ms/step - loss: 0.0494
# Epoch 22/300
# 41/41 - 0s - 2ms/step - loss: 0.0346
# Epoch 23/300
# 41/41 - 0s - 2ms/step - loss: 0.0262
# Epoch 24/300
# 41/41 - 0s - 2ms/step - loss: 0.0217
# Epoch 25/300
# 41/41 - 0s - 2ms/step - loss: 0.0192
# Epoch 26/300
# 41/41 - 0s - 2ms/step - loss: 0.0180
# Epoch 27/300
# 41/41 - 0s - 2ms/step - loss: 0.0174
# Epoch 28/300
# 41/41 - 0s - 2ms/step - loss: 0.0171
# Epoch 29/300
# 41/41 - 0s - 2ms/step - loss: 0.0169
# Epoch 30/300
# 41/41 - 0s - 2ms/step - loss: 0.0169
# Epoch 31/300
# 41/41 - 0s - 2ms/step - loss: 0.0169
# Epoch 32/300
# 41/41 - 0s - 2ms/step - loss: 0.0169
# Epoch 33/300
# 41/41 - 0s - 3ms/step - loss: 0.0169
# Epoch 34/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 35/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 36/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 37/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 38/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 39/300
# 41/41 - 0s - 3ms/step - loss: 0.0168
# Epoch 40/300
# 41/41 - 0s - 3ms/step - loss: 0.0168
# Epoch 41/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 42/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 43/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 44/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 45/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 46/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 47/300
# 41/41 - 0s - 2ms/step - loss: 0.0168
# Epoch 48/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 49/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 50/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 51/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 52/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 53/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 54/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 55/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 56/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 57/300
# 41/41 - 0s - 2ms/step - loss: 0.0167
# Epoch 58/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 59/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 60/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 61/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 62/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 63/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 64/300
# 41/41 - 0s - 2ms/step - loss: 0.0166
# Epoch 65/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 66/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 67/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 68/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 69/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 70/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 71/300
# 41/41 - 0s - 2ms/step - loss: 0.0165
# Epoch 72/300
# 41/41 - 0s - 2ms/step - loss: 0.0164
# Epoch 73/300
# 41/41 - 0s - 2ms/step - loss: 0.0164
# Epoch 74/300
# 41/41 - 0s - 2ms/step - loss: 0.0164
# Epoch 75/300
# 41/41 - 0s - 3ms/step - loss: 0.0164
# Epoch 76/300
# 41/41 - 0s - 2ms/step - loss: 0.0164
# Epoch 77/300
# 41/41 - 0s - 2ms/step - loss: 0.0164
# Epoch 78/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 79/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 80/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 81/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 82/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 83/300
# 41/41 - 0s - 2ms/step - loss: 0.0163
# Epoch 84/300
# 41/41 - 0s - 2ms/step - loss: 0.0162
# Epoch 85/300
# 41/41 - 0s - 3ms/step - loss: 0.0162
# Epoch 86/300
# 41/41 - 0s - 2ms/step - loss: 0.0162
# Epoch 87/300
# 41/41 - 0s - 2ms/step - loss: 0.0162
# Epoch 88/300
# 41/41 - 0s - 2ms/step - loss: 0.0161
# Epoch 89/300
# 41/41 - 0s - 2ms/step - loss: 0.0161
# Epoch 90/300
# 41/41 - 0s - 2ms/step - loss: 0.0161
# Epoch 91/300
# 41/41 - 0s - 2ms/step - loss: 0.0161
# Epoch 92/300
# 41/41 - 0s - 2ms/step - loss: 0.0160
# Epoch 93/300
# 41/41 - 0s - 2ms/step - loss: 0.0160
# Epoch 94/300
# 41/41 - 0s - 2ms/step - loss: 0.0160
# Epoch 95/300
# 41/41 - 0s - 2ms/step - loss: 0.0160
# Epoch 96/300
# 41/41 - 0s - 2ms/step - loss: 0.0159
# Epoch 97/300
# 41/41 - 0s - 2ms/step - loss: 0.0159
# Epoch 98/300
# 41/41 - 0s - 2ms/step - loss: 0.0159
# Epoch 99/300
# 41/41 - 0s - 2ms/step - loss: 0.0158
# Epoch 100/300
# 41/41 - 0s - 2ms/step - loss: 0.0158
# Epoch 101/300
# 41/41 - 0s - 2ms/step - loss: 0.0158
# Epoch 102/300
# 41/41 - 0s - 2ms/step - loss: 0.0157
# Epoch 103/300
# 41/41 - 0s - 2ms/step - loss: 0.0157
# Epoch 104/300
# 41/41 - 0s - 2ms/step - loss: 0.0157
# Epoch 105/300
# 41/41 - 0s - 2ms/step - loss: 0.0156
# Epoch 106/300
# 41/41 - 0s - 2ms/step - loss: 0.0156
# Epoch 107/300
# 41/41 - 0s - 2ms/step - loss: 0.0156
# Epoch 108/300
# 41/41 - 0s - 2ms/step - loss: 0.0155
# Epoch 109/300
# 41/41 - 0s - 2ms/step - loss: 0.0155
# Epoch 110/300
# 41/41 - 0s - 2ms/step - loss: 0.0154
# Epoch 111/300
# 41/41 - 0s - 2ms/step - loss: 0.0154
# Epoch 112/300
# 41/41 - 0s - 2ms/step - loss: 0.0153
# Epoch 113/300
# 41/41 - 0s - 2ms/step - loss: 0.0153
# Epoch 114/300
# 41/41 - 0s - 2ms/step - loss: 0.0152
# Epoch 115/300
# 41/41 - 0s - 3ms/step - loss: 0.0151
# Epoch 116/300
# 41/41 - 0s - 2ms/step - loss: 0.0151
# Epoch 117/300
# 41/41 - 0s - 2ms/step - loss: 0.0150
# Epoch 118/300
# 41/41 - 0s - 2ms/step - loss: 0.0149
# Epoch 119/300
# 41/41 - 0s - 2ms/step - loss: 0.0148
# Epoch 120/300
# 41/41 - 0s - 2ms/step - loss: 0.0146
# Epoch 121/300
# 41/41 - 0s - 2ms/step - loss: 0.0145
# Epoch 122/300
# 41/41 - 0s - 2ms/step - loss: 0.0144
# Epoch 123/300
# 41/41 - 0s - 2ms/step - loss: 0.0142
# Epoch 124/300
# 41/41 - 0s - 2ms/step - loss: 0.0140
# Epoch 125/300
# 41/41 - 0s - 2ms/step - loss: 0.0138
# Epoch 126/300
# 41/41 - 0s - 2ms/step - loss: 0.0136
# Epoch 127/300
# 41/41 - 0s - 2ms/step - loss: 0.0135
# Epoch 128/300
# 41/41 - 0s - 2ms/step - loss: 0.0133
# Epoch 129/300
# 41/41 - 0s - 2ms/step - loss: 0.0132
# Epoch 130/300
# 41/41 - 0s - 2ms/step - loss: 0.0130
# Epoch 131/300
# 41/41 - 0s - 2ms/step - loss: 0.0128
# Epoch 132/300
# 41/41 - 0s - 2ms/step - loss: 0.0127
# Epoch 133/300
# 41/41 - 0s - 2ms/step - loss: 0.0126
# Epoch 134/300
# 41/41 - 0s - 2ms/step - loss: 0.0125
# Epoch 135/300
# 41/41 - 0s - 2ms/step - loss: 0.0124
# Epoch 136/300
# 41/41 - 0s - 2ms/step - loss: 0.0122
# Epoch 137/300
# 41/41 - 0s - 2ms/step - loss: 0.0121
# Epoch 138/300
# 41/41 - 0s - 2ms/step - loss: 0.0120
# Epoch 139/300
# 41/41 - 0s - 2ms/step - loss: 0.0119
# Epoch 140/300
# 41/41 - 0s - 2ms/step - loss: 0.0118
# Epoch 141/300
# 41/41 - 0s - 2ms/step - loss: 0.0117
# Epoch 142/300
# 41/41 - 0s - 2ms/step - loss: 0.0116
# Epoch 143/300
# 41/41 - 0s - 2ms/step - loss: 0.0115
# Epoch 144/300
# 41/41 - 0s - 2ms/step - loss: 0.0114
# Epoch 145/300
# 41/41 - 0s - 2ms/step - loss: 0.0114
# Epoch 146/300
# 41/41 - 0s - 2ms/step - loss: 0.0112
# Epoch 147/300
# 41/41 - 0s - 2ms/step - loss: 0.0112
# Epoch 148/300
# 41/41 - 0s - 2ms/step - loss: 0.0112
# Epoch 149/300
# 41/41 - 0s - 2ms/step - loss: 0.0110
# Epoch 150/300
# 41/41 - 0s - 2ms/step - loss: 0.0111
# Epoch 151/300
# 41/41 - 0s - 2ms/step - loss: 0.0109
# Epoch 152/300
# 41/41 - 0s - 2ms/step - loss: 0.0108
# Epoch 153/300
# 41/41 - 0s - 2ms/step - loss: 0.0108
# Epoch 154/300
# 41/41 - 0s - 2ms/step - loss: 0.0107
# Epoch 155/300
# 41/41 - 0s - 2ms/step - loss: 0.0107
# Epoch 156/300
# 41/41 - 0s - 2ms/step - loss: 0.0106
# Epoch 157/300
# 41/41 - 0s - 2ms/step - loss: 0.0106
# Epoch 158/300
# 41/41 - 0s - 2ms/step - loss: 0.0105
# Epoch 159/300
# 41/41 - 0s - 2ms/step - loss: 0.0105
# Epoch 160/300
# 41/41 - 0s - 2ms/step - loss: 0.0104
# Epoch 161/300
# 41/41 - 0s - 2ms/step - loss: 0.0103
# Epoch 162/300
# 41/41 - 0s - 2ms/step - loss: 0.0103
# Epoch 163/300
# 41/41 - 0s - 2ms/step - loss: 0.0102
# Epoch 164/300
# 41/41 - 0s - 2ms/step - loss: 0.0102
# Epoch 165/300
# 41/41 - 0s - 2ms/step - loss: 0.0101
# Epoch 166/300
# 41/41 - 0s - 2ms/step - loss: 0.0101
# Epoch 167/300
# 41/41 - 0s - 2ms/step - loss: 0.0101
# Epoch 168/300
# 41/41 - 0s - 2ms/step - loss: 0.0100
# Epoch 169/300
# 41/41 - 0s - 2ms/step - loss: 0.0100
# Epoch 170/300
# 41/41 - 0s - 2ms/step - loss: 0.0100
# Epoch 171/300
# 41/41 - 0s - 2ms/step - loss: 0.0099
# Epoch 172/300
# 41/41 - 0s - 2ms/step - loss: 0.0099
# Epoch 173/300
# 41/41 - 0s - 2ms/step - loss: 0.0098
# Epoch 174/300
# 41/41 - 0s - 2ms/step - loss: 0.0098
# Epoch 175/300
# 41/41 - 0s - 2ms/step - loss: 0.0097
# Epoch 176/300
# 41/41 - 0s - 2ms/step - loss: 0.0097
# Epoch 177/300
# 41/41 - 0s - 2ms/step - loss: 0.0097
# Epoch 178/300
# 41/41 - 0s - 2ms/step - loss: 0.0097
# Epoch 179/300
# 41/41 - 0s - 2ms/step - loss: 0.0097
# Epoch 180/300
# 41/41 - 0s - 2ms/step - loss: 0.0096
# Epoch 181/300
# 41/41 - 0s - 2ms/step - loss: 0.0095
# Epoch 182/300
# 41/41 - 0s - 2ms/step - loss: 0.0095
# Epoch 183/300
# 41/41 - 0s - 2ms/step - loss: 0.0096
# Epoch 184/300
# 41/41 - 0s - 2ms/step - loss: 0.0094
# Epoch 185/300
# 41/41 - 0s - 2ms/step - loss: 0.0094
# Epoch 186/300
# 41/41 - 0s - 2ms/step - loss: 0.0094
# Epoch 187/300
# 41/41 - 0s - 2ms/step - loss: 0.0094
# Epoch 188/300
# 41/41 - 0s - 2ms/step - loss: 0.0093
# Epoch 189/300
# 41/41 - 0s - 1ms/step - loss: 0.0092
# Epoch 190/300
# 41/41 - 0s - 1ms/step - loss: 0.0093
# Epoch 191/300
# 41/41 - 0s - 2ms/step - loss: 0.0093
# Epoch 192/300
# 41/41 - 0s - 1ms/step - loss: 0.0092
# Epoch 193/300
# 41/41 - 0s - 1ms/step - loss: 0.0092
# Epoch 194/300
# 41/41 - 0s - 2ms/step - loss: 0.0092
# Epoch 195/300
# 41/41 - 0s - 2ms/step - loss: 0.0092
# Epoch 196/300
# 41/41 - 0s - 2ms/step - loss: 0.0092
# Epoch 197/300
# 41/41 - 0s - 2ms/step - loss: 0.0095
# Epoch 198/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 199/300
# 41/41 - 0s - 2ms/step - loss: 0.0092
# Epoch 200/300
# 41/41 - 0s - 2ms/step - loss: 0.0092
# Epoch 201/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 202/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 203/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 204/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 205/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 206/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 207/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 208/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 209/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 210/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 211/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 212/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 213/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 214/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 215/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 216/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 217/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 218/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 219/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 220/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 221/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 222/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 223/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 224/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 225/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 226/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 227/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 228/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 229/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 230/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 231/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 232/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 233/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 234/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 235/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 236/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 237/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 238/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 239/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 240/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 241/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 242/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 243/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 244/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 245/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 246/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 247/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 248/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 249/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 250/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 251/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 252/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 253/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 254/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 255/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 256/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 257/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 258/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 259/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 260/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 261/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 262/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 263/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 264/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 265/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 266/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 267/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 268/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 269/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 270/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 271/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 272/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 273/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 274/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 275/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 276/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 277/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 278/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 279/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 280/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 281/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 282/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 283/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 284/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 285/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 286/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 287/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 288/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 289/300
# 41/41 - 0s - 2ms/step - loss: 0.0091
# Epoch 290/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 291/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 292/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 293/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 294/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 295/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 296/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 297/300
# 41/41 - 0s - 2ms/step - loss: 0.0090
# Epoch 298/300
# 41/41 - 0s - 2ms/step - loss: 0.0089
# Epoch 299/300
# 41/41 - 0s - 2ms/step - loss: 0.0088
# Epoch 300/300
# 41/41 - 0s - 2ms/step - loss: 0.0088

# %%
# make predicttions

trainPredict = model.predict(trainX)
testPredict = model.predict(testX)

#invert predictions

trainPredict = np.expm1(trainPredict)
trainY = np.expm1(trainY)
testPredict = np.expm1(testPredict)
testY =np.expm1(testY)

#calculate root mean squared error
trainScore = math.sqrt(mean_squared_error(trainY, trainPredict[:,0]))
print('Train score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY, testPredict[:,0]))
print('Test score: %.2f RMSE' %(testScore))
# Out:
# 41/41 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 14/14 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Train score: 2.37 RMSE
# Test score: 3.15 RMSE

# %%
test_series = pd.Series(testY)

#state of model performance

if testScore < test_series.std():
    print('\n[ Model performance is GOOd enough ]')
    print('\nRMSE of test prediction < Standard deviation of the test dataset')
    print('%.2f' % (testScore), '<', '%.2f' %(test_series.std()))
else:
    print('\n[ Model performance is NOT GOOD enough ]')
    print('\nRMSE of test prediction > Standard deviation of the test dataset')
    print('%.2f' % (testScore), '>', '%.2f' %(test_series.std()))
# Out:
# [ Model performance is GOOd enough ]
#
# RMSE of test prediction < Standard deviation of the test dataset
# 3.15 < 4.41

# %%
#shift train predictions for plotting
trainPredictPlot = np.empty_like(dataset)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

#shift test predictions for plotting
testPredictPlot = np.empty_like(dataset)
testPredictPlot[:, :] = np.nan
testPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = testPredict

#plot original dataset and predictions
time_axis = np.linspace(0, dataset.shape[0]-1, 15)
time_axis = np.array([int(i) for i in time_axis])
time_axisLab = np.array(df2.index, dtype='datetime64[D]')

fig = plt.figure()
ax = fig.add_axes([0, 0, 2.1, 2])
ax.plot(np.expm1(dataset), label='Original Dataset')
ax.plot(trainPredictPlot, color='orange', label='Train Prediction')
ax.plot(testPredictPlot, color='red', label='Test Prediction')
ax.set_xticks(time_axis)
ax.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax.set_xlabel('\nDate', fontsize=27, fontweight='bold')
ax.set_ylabel('ISPU', fontsize=27, fontweight='bold')
ax.legend(loc='best', prop={'size':20})
ax.tick_params(size=10, labelsize=15)
ax.set_xlim([-1, 1735])

ax2 = fig.add_axes([2.3, 1.3, 1, 0.7])
ax2.plot(np.expm1(dataset), label='Original Dataset')
ax2.plot(testPredictPlot, color='red', label='Test Prediction')
ax2.set_xticks(time_axis)
ax2.set_xticklabels(time_axisLab[time_axis], rotation=45)
ax2.set_xlabel('\nDate', fontsize=27, fontweight='bold')
ax2.set_ylabel('ISPU', fontsize=27, fontweight='bold')
ax2.tick_params(size=10, labelsize=15)
ax2.set_xlim([1360, 1735])
# Out:
# (1360.0, 1735.0)
